# %%
# !pip install transformers accelerate torch scikit-learn matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 89.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 43.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 105.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install optuna sigopt wandb ray[tune]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.6/386.6 kB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 17.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.9/231.9 kB 20.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 13.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 MB 35.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
# ...

# %%
  pip install -U datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 17.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: datasets
#     Found existing installation: datasets 2.14.4
#     Uninstalling datasets-2.14.4:
#       Successfully uninstalled datasets-2.14.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ...

# %%
from datasets import load_dataset

dataset = load_dataset('jbarat/plant_species')
dataset
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/800 [00:00<?, ?B/s]
# (…)-00000-of-00001-15efca0bf2e6a460.parquet:   0%|          | 0.00/82.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/800 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 800
#     })
# })

# %%
import json
import os
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/NHERI_2025_SUMMER/"
# Out:
# /content/drive/MyDrive/NHERI_2025_SUMMER

# %%
dataset = load_dataset("imagefolder", data_dir="./train_2_split/")
# Out:
# Resolving data files:   0%|          | 0/1160 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# Split the training data into train and test (let's say 20% for the test set)
train_test_split = dataset['train'].train_test_split(test_size=0.1)

# Further split the training set to get a validation set (e.g., 10% of the training set)
train_val_split = train_test_split['train'].train_test_split(test_size=0.1)

# Combine the splits into a new DatasetDict
final_dataset = {
    'train': train_val_split['train'],
    'val': train_val_split['test'],  # Validation set
    'test': train_test_split['test']  # Test set
}

# Display the structure of the final dataset
final_dataset
# Out:
# {'train': Dataset({
#      features: ['image', 'label'],
#      num_rows: 939
#  }),
#  'val': Dataset({
#      features: ['image', 'label'],
#      num_rows: 105
#  }),
#  'test': Dataset({
#      features: ['image', 'label'],
#      num_rows: 116
#  })}

# %%
train_ds = final_dataset["train"]
val_ds = final_dataset["val"]
test_ds = final_dataset["test"]

# %%
train_ds[0]
# Out:
# {'image': <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600>,
#  'label': 1}

# %%
train_ds.features
# Out:
# {'image': Image(mode=None, decode=True, id=None),
#  'label': ClassLabel(names=['Collapsed', 'major_damage'], id=None)}

# %%
category_list=train_ds[:]['label']

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(category_list, bins=len(train_ds.features["label"].names), rwidth=1)
# Out:
# (array([102., 837.]),
#  array([0. , 0.5, 1. ]),
#  <BarContainer object of 2 artists>)

# %%
image = train_ds[0]['image']
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=800x600>

# %%
import matplotlib.pyplot as plt

# Initialize a set to keep track of shown labels
shown_labels = set()

# Initialize the figure for plotting
plt.figure(figsize=(15, 10))

# Loop through the dataset and plot the first image of each label
for i, sample in enumerate(train_ds):
    label = train_ds.features["label"].names[sample["label"]]
    if label not in shown_labels:
        plt.subplot(1, len(train_ds.features["label"].names), len(shown_labels) + 1)
        plt.imshow(sample["image"])
        plt.title(label)
        plt.axis("off")
        shown_labels.add(label)
        if len(shown_labels) == len(train_ds.features["label"].names):
            break

plt.show()

# %%
 train_ds.features["label"]
# Out:
# ClassLabel(names=['Collapsed', 'major_damage'], id=None)

# %%
plt.figure(figsize=(15, 10))
for i, sample in enumerate(val_ds):
    label = train_ds.features["label"].names[sample["label"]]

# %%
id2label = {id: label for id, label in enumerate(train_ds.features["label"].names)}
label2id = {label: id for id, label in id2label.items()}
id2label, id2label[train_ds[0]["label"]]
# Out:
# ({0: 'Collapsed', 1: 'major_damage'}, 'major_damage')

# %%
from transformers import ViTImageProcessor

model_name = "google/vit-base-patch16-224"
processor = ViTImageProcessor.from_pretrained(model_name)
processor
# Out:
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# ViTImageProcessor {
#   "do_convert_rgb": null,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "image_processor_type": "ViTImageProcessor",
#   "image_std": [
#     0.5,
#     0.5,
#     0.5
#   ],
#   "resample": 2,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "height": 224,
#     "width": 224
#   }
# }

# %%
from torchvision.transforms import (
    CenterCrop,
    Compose,
    Normalize,
    RandomHorizontalFlip,
    RandomResizedCrop,
    ToTensor,
    Resize,
)

image_mean, image_std = processor.image_mean, processor.image_std
size = processor.size["height"]

normalize = Normalize(mean=image_mean, std=image_std)

train_transforms = Compose(
    [
        RandomResizedCrop(size),
        RandomHorizontalFlip(),
        ToTensor(),
        normalize,
    ]
)
val_transforms = Compose(
    [
        Resize(size),
        CenterCrop(size),
        ToTensor(),
        normalize,
    ]
)
test_transforms = Compose(
    [
        Resize(size),
        CenterCrop(size),
        ToTensor(),
        normalize,
    ]
)

# %%
train_ds
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 939
# })

# %%
def apply_train_transforms(examples):
    examples["pixel_values"] = [train_transforms(image.convert("RGB")) for image in examples["image"]]
    return examples


def apply_val_transforms(examples):
    examples["pixel_values"] = [val_transforms(image.convert("RGB")) for image in examples["image"]]
    return examples


def apply_test_transforms(examples):
    examples["pixel_values"] = [val_transforms(image.convert("RGB")) for image in examples["image"]]
    return examples

train_ds.set_transform(apply_train_transforms)
val_ds.set_transform(apply_val_transforms)
test_ds.set_transform(apply_test_transforms)

# %%
import torch
from torch.utils.data import DataLoader


def collate_fn(examples):
    pixel_values = torch.stack([example["pixel_values"] for example in examples])
    labels = torch.tensor([example["label"] for example in examples])
    return {"pixel_values": pixel_values, "labels": labels}


train_dl = DataLoader(train_ds, collate_fn=collate_fn, batch_size=4)

# %%
batch = next(iter(train_dl))
for k, v in batch.items():
    if isinstance(v, torch.Tensor):
        print(k, v.shape)
# Out:
# pixel_values torch.Size([4, 3, 224, 224])
# labels torch.Size([4])

# %%
from transformers import ViTForImageClassification
labels  = dataset['train'].features['label'].names
model = ViTForImageClassification.from_pretrained(
    model_name,
    num_labels = len(labels),
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes=True
)
# Out:
# config.json:   0%|          | 0.00/69.7k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([2]) in the model instantiated
# ...

# %%
from transformers import TrainingArguments, Trainer
import numpy as np

train_args = TrainingArguments(
    output_dir="output-models",
  per_device_train_batch_size=100,
  eval_strategy="steps",
  num_train_epochs=10,
  fp16=True,
  save_steps=10,
  eval_steps=10,
  logging_steps=10,
  learning_rate=1e-5,
  save_total_limit=2,
  remove_unused_columns=False,
  push_to_hub=False,
  report_to='tensorboard',
  load_best_model_at_end=True,
)

# %%
trainer = Trainer(
    model,
    train_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    data_collator=collate_fn,
    tokenizer=processor,
)
trainer.train()
# Out:
# <ipython-input-29-dcebdcf50694>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='11' max='100' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 11/100 00:09 < 01:31, 0.97 it/s, Epoch 1/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='7' max='14' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 7/14 00:00 < 00:00, 8.87 it/s]
#     </div>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
outputs = trainer.predict(test_ds)
print(outputs.metrics)
# Out:
# {'test_loss': 0.1837252527475357, 'test_runtime': 2.8051, 'test_samples_per_second': 41.354, 'test_steps_per_second': 5.347}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = outputs.label_ids
y_pred = outputs.predictions.argmax(1)

labels = train_ds.features["label"].names
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(xticks_rotation=45)

# %%
from sklearn.metrics import classification_report

target_names = id2label.values()

print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    Collapsed       0.91      0.71      0.80        14
# major_damage       0.96      0.99      0.98       102
#
#     accuracy                           0.96       116
#    macro avg       0.94      0.85      0.89       116
# weighted avg       0.96      0.96      0.95       116

# %%
from sklearn.metrics import accuracy_score

# Calculate the accuracy score
accuracy = accuracy_score(y_true, y_pred)

# Print the accuracy
print(f"Accuracy: {accuracy:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-a4f64ab23a11> in <cell line: 0>()
#       2
#       3 # Calculate the accuracy score
# ----> 4 accuracy = accuracy_score(y_true, y_pred)
#       5
#       6 # Print the accuracy
#
# NameError: name 'y_true' is not defined

# %%
class CustomLossTrainer(Trainer):
    def __init__(self, *args, loss_fn=None, **kwargs):
        super().__init__(*args, **kwargs)
        # Store your custom loss function.
        # This should take (logits, labels) as arguments.
        self.loss_fn = loss_fn

    def compute_loss(self, model, inputs,  num_items_in_batch=None, return_outputs=False):
        # Assume your inputs include "labels" and your model returns logits.
        labels = inputs.get("labels")
        outputs = model(**inputs)
        logits = outputs.get("logits")

        # Compute the custom loss using your loss function.
        loss = self.loss_fn(logits, labels)

        return (loss, outputs) if return_outputs else loss

# %%
import torch.nn.functional as F

def weighted_ce(logits, labels):
    # Calculate standard cross-entropy loss first.
    weights=torch.tensor([1.0,0.1]).to(logits.device)
    ce_loss = F.cross_entropy(logits, labels, weight=weights)

    return ce_loss.mean()

# %%
from transformers import TrainingArguments

train_args = TrainingArguments(
    output_dir="output-models_model_2",
  per_device_train_batch_size=64,
  eval_strategy="steps",
  num_train_epochs=10,
  fp16=True,
  save_steps=10,
  eval_steps=10,
  logging_steps=10,
  learning_rate=1e-4,
  save_total_limit=2,
  remove_unused_columns=False,
  push_to_hub=False,
  report_to='tensorboard',
  load_best_model_at_end=True,
)

# %%
def focal_loss(logits, labels, alpha=0.25, gamma=2.0):
    # Calculate standard cross-entropy loss first.
    ce_loss = F.cross_entropy(logits, labels, reduction='none', weight=torch.tensor([1.0,0.1]).to(logits.device))
    pt = torch.exp(-ce_loss)
    focal_loss = alpha * (1 - pt) ** gamma * ce_loss
    return focal_loss.mean()

# %%
trainer = CustomLossTrainer(
    model=model,
    args=train_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    data_collator=collate_fn,
    loss_fn=focal_loss,  # Pass your custom loss function here.
)
trainer.train()
# Out:
#     <div>
#
#       <progress value='150' max='150' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [150/150 03:17, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.000100</td>
#       <td>0.024164</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.000100</td>
#       <td>0.059891</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.000300</td>
#       <td>0.019697</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.000200</td>
#       <td>0.020898</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.000100</td>
#       <td>0.011011</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.000200</td>
#       <td>0.013007</td>
#     </tr>
#     <tr>
#       <td>70</td>
# ...

# %%
outputs = trainer.predict(test_ds)
print(outputs.metrics)
# Out:
# {'test_loss': 0.01464738417416811, 'test_runtime': 3.7783, 'test_samples_per_second': 30.701, 'test_steps_per_second': 3.97}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_true = outputs.label_ids
y_pred = outputs.predictions.argmax(1)

labels = train_ds.features["label"].names
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(xticks_rotation=45)

# %%
from sklearn.metrics import classification_report

target_names = id2label.values()

print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#    Collapsed       0.41      0.64      0.50        14
# major_damage       0.95      0.87      0.91       102
#
#     accuracy                           0.84       116
#    macro avg       0.68      0.76      0.70       116
# weighted avg       0.88      0.84      0.86       116

# %%
def model_init(trial):
    # This function will be called by the hyperparameter search to create a new model for each trial
    return ViTForImageClassification.from_pretrained(
        model_name,
        num_labels=len(id2label), # Use the correct number of labels
        id2label=id2label,
        label2id=label2id,
        ignore_mismatched_sizes=True,
    )

# %%
trainer = CustomLossTrainer(
    model=None,  # Pass None for model here, as model_init will create it
    args=train_args,
    train_dataset=train_ds,  # Assuming train_ds is defined
    eval_dataset=val_ds,    # Assuming val_ds is defined
    data_collator=collate_fn, # Assuming collate_fn is defined
    loss_fn=weighted_ce,    # Pass your custom loss function here.
    model_init=model_init,  # Pass the model_init function here
)
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([2]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def optuna_hp_space(trial):
    return {
        "learning_rate": trial.suggest_float("learning_rate", 1e-6, 1e-4, log=True),
        "per_device_train_batch_size": trial.suggest_categorical("per_device_train_batch_size", [16, 32, 64]),
    }

best_trials = trainer.hyperparameter_search(
    direction=["minimize"],
    backend="optuna",
    hp_space=optuna_hp_space,
    n_trials=2,
)
# Out:
# [I 2025-05-15 17:57:14,434] A new study created in memory with name: no-name-6ea5e281-060d-4dc5-9061-71761a285c7e
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized because the shapes did not match:
# - classifier.bias: found shape torch.Size([1000]) in the checkpoint and torch.Size([2]) in the model instantiated
# - classifier.weight: found shape torch.Size([1000, 768]) in the checkpoint and torch.Size([2, 768]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 00:52, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
# ...

# %%
best_trials
# Out:
# BestRun(run_id='1', objective=0.3093988001346588, hyperparameters={'learning_rate': 2.6454453260348817e-05, 'per_device_train_batch_size': 32}, run_summary=None)

# %%
train_args = TrainingArguments(
    output_dir="output-models_model_2",
  per_device_train_batch_size=32,
  eval_strategy="steps",
  num_train_epochs=10,
  fp16=True,
  save_steps=10,
  eval_steps=10,
  logging_steps=10,
  learning_rate=2.6454453260348817e-05,
  save_total_limit=2,
  remove_unused_columns=False,
  push_to_hub=False,
  report_to='tensorboard',
  load_best_model_at_end=True,
)

# %%
trainer = CustomLossTrainer(
    model=model,
    args=train_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    data_collator=collate_fn,
    loss_fn=weighted_ce,  # Pass your custom loss function here.
)
trainer.train()
# Out:
#     <div>
#
#       <progress value='300' max='300' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [300/300 05:57, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.364000</td>
#       <td>0.436773</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.485700</td>
#       <td>0.370010</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.435000</td>
#       <td>0.314413</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.335300</td>
#       <td>0.289535</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.498900</td>
#       <td>0.226970</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.403500</td>
#       <td>0.204086</td>
#     </tr>
#     <tr>
#       <td>70</td>
# ...

# %%
# Out:
# {'test_loss': 0.2713274657726288, 'test_runtime': 60.3008, 'test_samples_per_second': 1.924, 'test_steps_per_second': 0.249}

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

outputs = trainer.predict(test_ds)
print(outputs.metrics)

y_true = outputs.label_ids
y_pred = outputs.predictions.argmax(1)

labels = train_ds.features["label"].names
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(xticks_rotation=45)

# %%
ls
# Out:
#  2025_nsf_nheri_gsc_data_challenge_v2.pptx
#  finetuning_transfomers_NHERI.ipynb
#  information_fusion.ipynb
#  output-models/
# 'output-models (1)'/
#  output-models_model_2/
#  results/
# 'Supervised_fine_tuning_(SFT)_of_an_LLM_using_Hugging_Face_tooling.ipynb'
#  train/
#  train_2_split/
#  train_model_0/

# %%
output_dir= './output-models_model_2/checkpoint-300/'

# %%
target_names = id2label.values()

print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-d89de191712f> in <cell line: 0>()
#       1 target_names = id2label.values()
#       2
# ----> 3 print(classification_report(y_true, y_pred, target_names=target_names))
#
# NameError: name 'classification_report' is not defined

# %%
model = ViTForImageClassification.from_pretrained(output_dir, device_map="auto")

# %%
test_ds
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 116
# })

# %%
from transformers import AutoImageProcessor

# %%
image_processor = AutoImageProcessor.from_pretrained("google/vit-base-patch16-224-in21k")
inputs = image_processor(test_ds[0]['image'], return_tensors="pt")
inputs = inputs.to(model.device)
outputs_for_model=model(**inputs)
outputs_for_model
# Out:
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# ImageClassifierOutput(loss=None, logits=tensor([[-1.3212,  1.9375]], device='cuda:0', grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)

# %%
# Access the logits from the output
logits = outputs_for_model.logits

# If you want the predicted class index
predicted_class_idx = logits.argmax(dim=-1)

# If you want the predicted class label
predicted_class_label = model.config.id2label[predicted_class_idx.item()]

# You can print these to see the output
print("Logits:", logits)
print("Predicted Class Index:", predicted_class_idx)
print("Predicted Class Label:", predicted_class_label)

# If you intended to get hidden states, you would need to modify how you load the model
# from transformers import ViTModel # Import the base model if needed
# model = ViTForImageClassification.from_pretrained(output_dir, device_map="auto", output_hidden_states=True)
# Then you could access outputs_for_model.hidden_states
# Out:
# Logits: tensor([[-1.3212,  1.9375]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Predicted Class Index: tensor([1], device='cuda:0')
# Predicted Class Label: major_damage

# %%
import torch

# %%
probs, indices = torch.topk(outputs_for_model.logits.softmax(dim=1), k=2)

# %%
probs
# Out:
# tensor([[0.9630, 0.0370]], device='cuda:0', grad_fn=<TopkBackward0>)

# %%
def get_prediction_probs(model, url_or_path, num_classes=3):
    # load the image
    img = load_image(url_or_path)
    # preprocessing the image
    pixel_values = image_processor(img, return_tensors="pt")["pixel_values"].to(device)
    # perform inference
    output = model(pixel_values)
    # get the top k classes and probabilities
    probs, indices = torch.topk(output.logits.softmax(dim=1), k=num_classes)
    # get the class labels
    id2label = model.config.id2label
    classes = [id2label[idx.item()] for idx in indices[0]]
    # convert the probabilities to a list
    probs = probs.squeeze().tolist()
    # create a dictionary with the class names and probabilities
    results = dict(zip(classes, probs))
    return results

# %%
# Out:
# ImageClassifierOutput(loss=None, logits=tensor([[-1.3212,  1.9375]], device='cuda:0', grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)

# %% [markdown]
# **MODEL 0:**

# %%
dataset = load_dataset("imagefolder", data_dir="./train_model_0/")
# Out:
# Resolving data files:   0%|          | 0/1880 [00:00<?, ?it/s]
# ...
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# Split the training data into train and test (let's say 20% for the test set)
train_test_split = dataset['train'].train_test_split(test_size=0.1)

# Further split the training set to get a validation set (e.g., 10% of the training set)
train_val_split = train_test_split['train'].train_test_split(test_size=0.1)

# Combine the splits into a new DatasetDict
final_dataset = {
    'train': train_val_split['train'],
    'val': train_val_split['test'],  # Validation set
    'test': train_test_split['test']  # Test set
}

# Display the structure of the final dataset
train_ds = final_dataset["train"]
val_ds = final_dataset["val"]
test_ds = final_dataset["test"]

id2label = {id: label for id, label in enumerate(train_ds.features["label"].names)}
label2id = {label: id for id, label in id2label.items()}
id2label, id2label[train_ds[0]["label"]]
# Out:
# {'train': Dataset({
#      features: ['image', 'label'],
#      num_rows: 1522
#  }),
#  'val': Dataset({
#      features: ['image', 'label'],
#      num_rows: 170
#  }),
#  'test': Dataset({
#      features: ['image', 'label'],
#      num_rows: 188
#  })}

# %%
# Out:
# ({0: 'major_damage', 1: 'non_major_damage'}, 'non_major_damage')

# %%
id2label
# Out:
# {0: 'major_damage', 1: 'non_major_damage'}

# %%
from transformers import TrainingArguments, Trainer
import numpy as np

train_args = TrainingArguments(
    output_dir="output-models-MODEL0",
  per_device_train_batch_size=100,
  eval_strategy="steps",
  num_train_epochs=5,
  fp16=True,
  save_steps=10,
  eval_steps=10,
  logging_steps=10,
  learning_rate=1e-5,
  save_total_limit=2,
  remove_unused_columns=False,
  push_to_hub=False,
  report_to='tensorboard',
  load_best_model_at_end=True,
)

# %%
def apply_train_transforms(examples):
    examples["pixel_values"] = [train_transforms(image.convert("RGB")) for image in examples["image"]]
    return examples


def apply_val_transforms(examples):
    examples["pixel_values"] = [val_transforms(image.convert("RGB")) for image in examples["image"]]
    return examples


def apply_test_transforms(examples):
    examples["pixel_values"] = [val_transforms(image.convert("RGB")) for image in examples["image"]]
    return examples

train_ds.set_transform(apply_train_transforms)
val_ds.set_transform(apply_val_transforms)
test_ds.set_transform(apply_test_transforms)

# %%
trainer = Trainer(
    model,
    train_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    data_collator=collate_fn,
    tokenizer=processor,
)
trainer.train()
# Out:
# <ipython-input-86-dcebdcf50694>:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
#     <div>
#
#       <progress value='80' max='80' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [80/80 04:01, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.726800</td>
#       <td>0.625838</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.580200</td>
#       <td>0.506324</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.451600</td>
#       <td>0.459755</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.452800</td>
#       <td>0.451301</td>
#     </tr>
#     <tr>
#       <td>50</td>
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

outputs = trainer.predict(test_ds)
print(outputs.metrics)

y_true = outputs.label_ids
y_pred = outputs.predictions.argmax(1)

labels = train_ds.features["label"].names
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(xticks_rotation=45)
# Out:
# {'test_loss': 0.37426555156707764, 'test_runtime': 28.6541, 'test_samples_per_second': 6.561, 'test_steps_per_second': 0.838}
